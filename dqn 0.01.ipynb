# %% [markdown]
# # DQN Implementation for CartPole environment

# %% [markdown]
# ## Import required libraries

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\anaconda3\lib\site-packages (from gym) (1.21.5)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\anaconda3\lib\site-packages (from gym) (4.11.3)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\anaconda3\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\anaconda3\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.8.0)

# %%
import json
import random
import time
from collections import deque

import gym
import keras
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %% [markdown]
# ## Define DQNAgent Class

# %%
class DQNAgent:
    
    def __init__(self, state_size, action_size):

        self.state_size = state_size
        self.action_size = action_size
        
        # Initialize Replay Buffer as python deque
        self.replay_buffer = deque(maxlen=100000)
        
        # Set algorithm hyperparameters
        self.gamma = 0.99
        self.epsilon = 1.
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.98
        self.learning_rate = 0.01
        self.update_rate = 10
        
        # Create both Main and Target Networks
        self.main_network = self.create_nn()
        self.target_network = self.create_nn()
        
        # Initialize Target Network with Main Network's weights
        self.update_target_network()

    def create_nn(self):
        
        model = Sequential()

        model.add(Dense(64, activation='relu', input_dim=self.state_size))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))

        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))

        return model
    
    def update_target_network(self):
        # Method to set the Main NN's weights on the Target NN
        self.target_network.set_weights(self.main_network.get_weights())

    def save_experience(self, state, action, reward, next_state, terminal):
        
        # Save the given experience as a (s, a, r, s', terminal) tuple
        self.replay_buffer.append((state, action, reward, next_state, terminal))

    def sample_experience_batch(self, batch_size):
        
        # Sample {batchsize} experiences from the ReplayBuffer
        exp_batch = random.sample(self.replay_buffer, batch_size)

        # Create an array with the {batchsize} elements for s, a, r, s' and terminal information
        state_batch = np.array([batch[0] for batch in exp_batch]).reshape(batch_size, self.state_size)
        action_batch = np.array([batch[1] for batch in exp_batch])
        reward_batch = [batch[2] for batch in exp_batch]
        next_state_batch = np.array([batch[3] for batch in exp_batch]).reshape(batch_size, self.state_size)
        terminal_batch = [batch[4] for batch in exp_batch]

        # Return a tuple, where each item corresponds to each array/batch created above
        return state_batch, action_batch, reward_batch, next_state_batch, terminal_batch

    def pick_epsilon_greedy_action(self, state):

        # Pick random action with probability ε
        if random.uniform(0, 1) < self.epsilon:
            return np.random.randint(self.action_size)

        # Pick action with highest Q-Value (item with highest value for Main NN's output)
        state = state.reshape((1, self.state_size))
        q_values = self.main_network.predict(state, verbose=0)
        return np.argmax(q_values[0])

    def train(self, batch_size):

        # Sample a batch of experiences
        state_batch, action_batch, reward_batch, next_state_batch, terminal_batch = self.sample_experience_batch(batch_size)

        # Get the actions with highest Q-Value for the batch of next states
        next_q = self.target_network.predict(next_state_batch, verbose=0)
        max_next_q = np.amax(next_q, axis=1)
        # Get the Q-values of each state in the batch of states
        q_values = self.main_network.predict(state_batch, verbose=0)

        # Update the Q-Value corresponding to the current action with the Target Value
        for i in range(batch_size):
            q_values[i][action_batch[i]] = reward_batch[i] if terminal_batch[i] else reward_batch[i] + self.gamma * max_next_q[i]

        # Fit the network
        self.main_network.fit(state_batch, q_values, verbose=0)

# %% [markdown]
# ## Implement flow for DQN algorithm

# %% [markdown]
# ### 1. Initialize Gym Environment

# %%
# Initialize CartPole environment
env = gym.make('CartPole-v1')

# Define state and action size
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %% [markdown]
# ### 2. Define number of episodes, timesteps per episode and batch size

# %%
num_episodes = 100
num_timesteps = 350
batch_size = 64

# %% [markdown]
# ### 3. Initlaize DQNAgent

# %%
dqn_agent = DQNAgent(state_size, action_size)

# %% [markdown]
# ### 4. Implement and execute flow of DQN algorithm

# %%
rewards, epsilon_values, learning_rate_values = list(), list(), list() # Lists to keep logs of rewards and apsilon values, for plotting later
time_step = 0 # Initalize timestep counter

for ep in range(num_episodes):
    
    tot_reward = 0
    state, _ = env.reset()
    
    print(f'\nTraining on EPISODE {ep+1} with epsilon {dqn_agent.epsilon}')
    start = time.time()
    
    for t in range(num_timesteps):
        
        time_step += 1
        
        # Update Target Network every {dqn_agent.update_rate} timesteps
        if time_step % dqn_agent.update_rate == 0:
            dqn_agent.update_target_network()
            
        action = dqn_agent.pick_epsilon_greedy_action(state) # Select action with ε-greedy policy
        next_state, reward, terminal, _, _ = env.step(action) # Perform action on environment
        dqn_agent.save_experience(state, action, reward, next_state, terminal) # Save experience in ReplayBuffer

        state = next_state
        tot_reward += reward

        if terminal:
            print('Episode: ', ep+1, ' terminated with Reward ', tot_reward)
            break

        # Train the Main Network when ReplayBuffer has enough experiences to fill a batch
        if len(dqn_agent.replay_buffer) > batch_size:
            dqn_agent.train(batch_size)

    rewards.append(tot_reward)
    epsilon_values.append(dqn_agent.epsilon)
    
    # Everytime an episode is finished, update Epsilon value to a lower value
    if dqn_agent.epsilon > dqn_agent.epsilon_min:
        dqn_agent.epsilon *= dqn_agent.epsilon_decay
        
    # Print information about the Episode performed
    elapsed = time.time() - start
    print(f'Time elapsed during EPISODE {ep+1}: {elapsed} seconds = {round(elapsed/60, 3)} minutes')

    # If the agent got a reward >499 in each of the last 10 episodes, the training is terminated
    if sum(rewards[-10:]) > 4990:
        print('Training stopped because agent has performed a perfect episode in the last 10 episodes')
        break
# Out:
# Training on EPISODE 1 with epsilon 1.0
# Episode:  1  terminated with Reward  11.0
# Time elapsed during EPISODE 1: 0.0 seconds = 0.0 minutes
#
# Training on EPISODE 2 with epsilon 0.98
# Episode:  2  terminated with Reward  65.0
# Time elapsed during EPISODE 2: 1.7362034320831299 seconds = 0.029 minutes
#
# Training on EPISODE 3 with epsilon 0.9603999999999999
# Episode:  3  terminated with Reward  13.0
# Time elapsed during EPISODE 3: 1.427830457687378 seconds = 0.024 minutes
#
# Training on EPISODE 4 with epsilon 0.9411919999999999
# Episode:  4  terminated with Reward  10.0
# Time elapsed during EPISODE 4: 0.9900939464569092 seconds = 0.017 minutes
#
# Training on EPISODE 5 with epsilon 0.9223681599999999
# Episode:  5  terminated with Reward  30.0
# Time elapsed during EPISODE 5: 3.365548610687256 seconds = 0.056 minutes
#
# Training on EPISODE 6 with epsilon 0.9039207967999998
# Episode:  6  terminated with Reward  10.0
# Time elapsed during EPISODE 6: 0.988602876663208 seconds = 0.016 minutes
#
# Training on EPISODE 7 with epsilon 0.8858423808639998
# Episode:  7  terminated with Reward  10.0
# Time elapsed during EPISODE 7: 1.063183307647705 seconds = 0.018 minutes
#
# Training on EPISODE 8 with epsilon 0.8681255332467198
# Episode:  8  terminated with Reward  27.0
# Time elapsed during EPISODE 8: 2.923658609390259 seconds = 0.049 minutes
#
# Training on EPISODE 9 with epsilon 0.8507630225817854
# Episode:  9  terminated with Reward  18.0
# Time elapsed during EPISODE 9: 1.9822626113891602 seconds = 0.033 minutes
#
# Training on EPISODE 10 with epsilon 0.8337477621301497
# Episode:  10  terminated with Reward  46.0
# Time elapsed during EPISODE 10: 5.23509407043457 seconds = 0.087 minutes
#
# Training on EPISODE 11 with epsilon 0.8170728068875467
# Episode:  11  terminated with Reward  34.0
# Time elapsed during EPISODE 11: 3.9647927284240723 seconds = 0.066 minutes
#
# Training on EPISODE 12 with epsilon 0.8007313507497957
# Episode:  12  terminated with Reward  14.0
# Time elapsed during EPISODE 12: 1.4229075908660889 seconds = 0.024 minutes
#
# Training on EPISODE 13 with epsilon 0.7847167237347998
# Episode:  13  terminated with Reward  17.0
# Time elapsed during EPISODE 13: 1.8988897800445557 seconds = 0.032 minutes
#
# Training on EPISODE 14 with epsilon 0.7690223892601038
# Episode:  14  terminated with Reward  13.0
# Time elapsed during EPISODE 14: 1.4300422668457031 seconds = 0.024 minutes
#
# Training on EPISODE 15 with epsilon 0.7536419414749017
# Episode:  15  terminated with Reward  30.0
# Time elapsed during EPISODE 15: 3.62575364112854 seconds = 0.06 minutes
#
# Training on EPISODE 16 with epsilon 0.7385691026454037
# Episode:  16  terminated with Reward  59.0
# Time elapsed during EPISODE 16: 6.86408805847168 seconds = 0.114 minutes
#
# Training on EPISODE 17 with epsilon 0.7237977205924956
# Episode:  17  terminated with Reward  35.0
# Time elapsed during EPISODE 17: 4.198858737945557 seconds = 0.07 minutes
#
# Training on EPISODE 18 with epsilon 0.7093217661806457
# Episode:  18  terminated with Reward  31.0
# Time elapsed during EPISODE 18: 3.628096342086792 seconds = 0.06 minutes
#
# Training on EPISODE 19 with epsilon 0.6951353308570327
# Episode:  19  terminated with Reward  12.0
# Time elapsed during EPISODE 19: 1.2906944751739502 seconds = 0.022 minutes
#
# Training on EPISODE 20 with epsilon 0.6812326242398921
# Episode:  20  terminated with Reward  29.0
# Time elapsed during EPISODE 20: 3.346102476119995 seconds = 0.056 minutes
#
# Training on EPISODE 21 with epsilon 0.6676079717550942
# Episode:  21  terminated with Reward  157.0
# Time elapsed during EPISODE 21: 19.3321692943573 seconds = 0.322 minutes
#
# Training on EPISODE 22 with epsilon 0.6542558123199923
# Episode:  22  terminated with Reward  14.0
# Time elapsed during EPISODE 22: 1.6337218284606934 seconds = 0.027 minutes
#
# Training on EPISODE 23 with epsilon 0.6411706960735924
# Episode:  23  terminated with Reward  45.0
# Time elapsed during EPISODE 23: 5.557235956192017 seconds = 0.093 minutes
#
# Training on EPISODE 24 with epsilon 0.6283472821521205
# Episode:  24  terminated with Reward  78.0
# Time elapsed during EPISODE 24: 9.671555995941162 seconds = 0.161 minutes
#
# Training on EPISODE 25 with epsilon 0.6157803365090782
# Episode:  25  terminated with Reward  41.0
# Time elapsed during EPISODE 25: 5.324826717376709 seconds = 0.089 minutes
#
# Training on EPISODE 26 with epsilon 0.6034647297788965
# Episode:  26  terminated with Reward  42.0
# Time elapsed during EPISODE 26: 5.29948353767395 seconds = 0.088 minutes
#
# Training on EPISODE 27 with epsilon 0.5913954351833186
# Episode:  27  terminated with Reward  15.0
# Time elapsed during EPISODE 27: 1.8943889141082764 seconds = 0.032 minutes
#
# Training on EPISODE 28 with epsilon 0.5795675264796523
# Episode:  28  terminated with Reward  39.0
# Time elapsed during EPISODE 28: 4.891690254211426 seconds = 0.082 minutes
#
# Training on EPISODE 29 with epsilon 0.5679761759500592
# Episode:  29  terminated with Reward  43.0
# Time elapsed during EPISODE 29: 5.267493486404419 seconds = 0.088 minutes
#
# Training on EPISODE 30 with epsilon 0.5566166524310581
# Episode:  30  terminated with Reward  14.0
# Time elapsed during EPISODE 30: 1.61753249168396 seconds = 0.027 minutes
#
# Training on EPISODE 31 with epsilon 0.5454843193824369
# Episode:  31  terminated with Reward  25.0
# Time elapsed during EPISODE 31: 2.922240972518921 seconds = 0.049 minutes
#
# Training on EPISODE 32 with epsilon 0.5345746329947881
# Episode:  32  terminated with Reward  64.0
# Time elapsed during EPISODE 32: 7.886932373046875 seconds = 0.131 minutes
#
# Training on EPISODE 33 with epsilon 0.5238831403348924
# Episode:  33  terminated with Reward  86.0
# Time elapsed during EPISODE 33: 10.598053455352783 seconds = 0.177 minutes
#
# Training on EPISODE 34 with epsilon 0.5134054775281945
# Episode:  34  terminated with Reward  42.0
# Time elapsed during EPISODE 34: 5.351075887680054 seconds = 0.089 minutes
#
# Training on EPISODE 35 with epsilon 0.5031373679776306
# Episode:  35  terminated with Reward  40.0
# Time elapsed during EPISODE 35: 4.94947075843811 seconds = 0.082 minutes
#
# Training on EPISODE 36 with epsilon 0.493074620618078
# Episode:  36  terminated with Reward  73.0
# Time elapsed during EPISODE 36: 9.5020112991333 seconds = 0.158 minutes
#
# Training on EPISODE 37 with epsilon 0.48321312820571644
# Episode:  37  terminated with Reward  65.0
# Time elapsed during EPISODE 37: 8.222702026367188 seconds = 0.137 minutes
#
# Training on EPISODE 38 with epsilon 0.4735488656416021
# Episode:  38  terminated with Reward  142.0
# Time elapsed during EPISODE 38: 19.081971883773804 seconds = 0.318 minutes
#
# Training on EPISODE 39 with epsilon 0.46407788832877006
# Episode:  39  terminated with Reward  74.0
# Time elapsed during EPISODE 39: 9.76874566078186 seconds = 0.163 minutes
#
# Training on EPISODE 40 with epsilon 0.45479633056219465
# Episode:  40  terminated with Reward  111.0
# Time elapsed during EPISODE 40: 14.600269079208374 seconds = 0.243 minutes
#
# Training on EPISODE 41 with epsilon 0.44570040395095073
# Episode:  41  terminated with Reward  130.0
# Time elapsed during EPISODE 41: 17.15958857536316 seconds = 0.286 minutes
#
# Training on EPISODE 42 with epsilon 0.4367863958719317
# Episode:  42  terminated with Reward  132.0
# Time elapsed during EPISODE 42: 17.483469247817993 seconds = 0.291 minutes
#
# Training on EPISODE 43 with epsilon 0.42805066795449304
# Episode:  43  terminated with Reward  71.0
# Time elapsed during EPISODE 43: 8.766636848449707 seconds = 0.146 minutes
#
# Training on EPISODE 44 with epsilon 0.41948965459540316
# Episode:  44  terminated with Reward  131.0
# Time elapsed during EPISODE 44: 17.147421836853027 seconds = 0.286 minutes
#
# Training on EPISODE 45 with epsilon 0.4110998615034951
# Episode:  45  terminated with Reward  44.0
# Time elapsed during EPISODE 45: 5.75636887550354 seconds = 0.096 minutes
#
# Training on EPISODE 46 with epsilon 0.4028778642734252
# Episode:  46  terminated with Reward  35.0
# Time elapsed during EPISODE 46: 4.3798346519470215 seconds = 0.073 minutes
#
# Training on EPISODE 47 with epsilon 0.39482030698795667
# Episode:  47  terminated with Reward  15.0
# Time elapsed during EPISODE 47: 1.8728785514831543 seconds = 0.031 minutes
#
# Training on EPISODE 48 with epsilon 0.38692390084819756
# Episode:  48  terminated with Reward  19.0
# Time elapsed during EPISODE 48: 2.452096700668335 seconds = 0.041 minutes
#
# Training on EPISODE 49 with epsilon 0.3791854228312336
# Episode:  49  terminated with Reward  22.0
# Time elapsed during EPISODE 49: 2.784545660018921 seconds = 0.046 minutes
#
# Training on EPISODE 50 with epsilon 0.37160171437460887
# Episode:  50  terminated with Reward  126.0
# Time elapsed during EPISODE 50: 16.52764630317688 seconds = 0.275 minutes
#
# Training on EPISODE 51 with epsilon 0.3641696800871167
# Episode:  51  terminated with Reward  132.0
# Time elapsed during EPISODE 51: 17.43661904335022 seconds = 0.291 minutes
#
# Training on EPISODE 52 with epsilon 0.35688628648537435
# Episode:  52  terminated with Reward  127.0
# Time elapsed during EPISODE 52: 17.08508324623108 seconds = 0.285 minutes
#
# Training on EPISODE 53 with epsilon 0.34974856075566685
# Episode:  53  terminated with Reward  192.0
# Time elapsed during EPISODE 53: 25.799129247665405 seconds = 0.43 minutes
#
# Training on EPISODE 54 with epsilon 0.3427535895405535
# Episode:  54  terminated with Reward  234.0
# Time elapsed during EPISODE 54: 31.393316745758057 seconds = 0.523 minutes
#
# Training on EPISODE 55 with epsilon 0.33589851774974244
# Episode:  55  terminated with Reward  128.0
# Time elapsed during EPISODE 55: 17.026872158050537 seconds = 0.284 minutes
#
# Training on EPISODE 56 with epsilon 0.3291805473947476
# Episode:  56  terminated with Reward  91.0
# Time elapsed during EPISODE 56: 12.984463214874268 seconds = 0.216 minutes
#
# Training on EPISODE 57 with epsilon 0.32259693644685267
# Episode:  57  terminated with Reward  93.0
# Time elapsed during EPISODE 57: 13.949825525283813 seconds = 0.232 minutes
#
# Training on EPISODE 58 with epsilon 0.3161449977179156
# Episode:  58  terminated with Reward  42.0
# Time elapsed during EPISODE 58: 6.083053350448608 seconds = 0.101 minutes
#
# Training on EPISODE 59 with epsilon 0.3098220977635573
# Episode:  59  terminated with Reward  88.0
# Time elapsed during EPISODE 59: 12.452390193939209 seconds = 0.208 minutes
#
# Training on EPISODE 60 with epsilon 0.30362565580828615
# Episode:  60  terminated with Reward  84.0
# Time elapsed during EPISODE 60: 11.45607328414917 seconds = 0.191 minutes
#
# Training on EPISODE 61 with epsilon 0.2975531426921204
# Episode:  61  terminated with Reward  49.0
# Time elapsed during EPISODE 61: 6.977495431900024 seconds = 0.116 minutes
#
# Training on EPISODE 62 with epsilon 0.291602079838278
# Episode:  62  terminated with Reward  13.0
# Time elapsed during EPISODE 62: 1.6260979175567627 seconds = 0.027 minutes
#
# Training on EPISODE 63 with epsilon 0.2857700382415124
# Episode:  63  terminated with Reward  13.0
# Time elapsed during EPISODE 63: 1.7007336616516113 seconds = 0.028 minutes
#
# Training on EPISODE 64 with epsilon 0.2800546374766822
# Episode:  64  terminated with Reward  249.0
# Time elapsed during EPISODE 64: 34.13672757148743 seconds = 0.569 minutes
#
# Training on EPISODE 65 with epsilon 0.27445354472714856
# Episode:  65  terminated with Reward  147.0
# Time elapsed during EPISODE 65: 20.246402502059937 seconds = 0.337 minutes
#
# Training on EPISODE 66 with epsilon 0.2689644738326056
# Episode:  66  terminated with Reward  261.0
# Time elapsed during EPISODE 66: 35.99180889129639 seconds = 0.6 minutes
#
# Training on EPISODE 67 with epsilon 0.26358518435595346
# Episode:  67  terminated with Reward  169.0
# Time elapsed during EPISODE 67: 23.419853448867798 seconds = 0.39 minutes
#
# Training on EPISODE 68 with epsilon 0.25831348066883436
# Episode:  68  terminated with Reward  330.0
# Time elapsed during EPISODE 68: 45.3819682598114 seconds = 0.756 minutes
#
# Training on EPISODE 69 with epsilon 0.2531472110554577
# Episode:  69  terminated with Reward  307.0
# Time elapsed during EPISODE 69: 43.03623867034912 seconds = 0.717 minutes
#
# Training on EPISODE 70 with epsilon 0.24808426683434853
# Episode:  70  terminated with Reward  222.0
# Time elapsed during EPISODE 70: 31.032443523406982 seconds = 0.517 minutes
#
# Training on EPISODE 71 with epsilon 0.24312258149766156
# Episode:  71  terminated with Reward  192.0
# Time elapsed during EPISODE 71: 27.253069639205933 seconds = 0.454 minutes
#
# Training on EPISODE 72 with epsilon 0.2382601298677083
# Episode:  72  terminated with Reward  15.0
# Time elapsed during EPISODE 72: 2.0007410049438477 seconds = 0.033 minutes
#
# Training on EPISODE 73 with epsilon 0.23349492727035415
# Episode:  73  terminated with Reward  16.0
# Time elapsed during EPISODE 73: 2.1140947341918945 seconds = 0.035 minutes
#
# Training on EPISODE 74 with epsilon 0.22882502872494706
# Episode:  74  terminated with Reward  45.0
# Time elapsed during EPISODE 74: 6.45613169670105 seconds = 0.108 minutes
#
# Training on EPISODE 75 with epsilon 0.22424852815044813
# Episode:  75  terminated with Reward  21.0
# Time elapsed during EPISODE 75: 2.8048617839813232 seconds = 0.047 minutes
#
# Training on EPISODE 76 with epsilon 0.21976355758743915
# Episode:  76  terminated with Reward  321.0
# Time elapsed during EPISODE 76: 44.924068212509155 seconds = 0.749 minutes
#
# Training on EPISODE 77 with epsilon 0.21536828643569036
# Episode:  77  terminated with Reward  28.0
# Time elapsed during EPISODE 77: 3.8971009254455566 seconds = 0.065 minutes
#
# Training on EPISODE 78 with epsilon 0.21106092070697655
# Episode:  78  terminated with Reward  141.0
# Time elapsed during EPISODE 78: 20.067901372909546 seconds = 0.334 minutes
#
# Training on EPISODE 79 with epsilon 0.20683970229283702
# Episode:  79  terminated with Reward  24.0
# Time elapsed during EPISODE 79: 3.2543857097625732 seconds = 0.054 minutes
#
# Training on EPISODE 80 with epsilon 0.20270290824698028
# Episode:  80  terminated with Reward  94.0
# Time elapsed during EPISODE 80: 13.260644674301147 seconds = 0.221 minutes
#
# Training on EPISODE 81 with epsilon 0.19864885008204067
# Episode:  81  terminated with Reward  65.0
# Time elapsed during EPISODE 81: 8.97955322265625 seconds = 0.15 minutes
#
# Training on EPISODE 82 with epsilon 0.19467587308039985
# Episode:  82  terminated with Reward  13.0
# Time elapsed during EPISODE 82: 1.7325584888458252 seconds = 0.029 minutes
#
# Training on EPISODE 83 with epsilon 0.19078235561879187
# Episode:  83  terminated with Reward  25.0
# Time elapsed during EPISODE 83: 3.3353676795959473 seconds = 0.056 minutes
#
# Training on EPISODE 84 with epsilon 0.18696670850641603
# Episode:  84  terminated with Reward  38.0
# Time elapsed during EPISODE 84: 4.98322606086731 seconds = 0.083 minutes
#
# Training on EPISODE 85 with epsilon 0.18322737433628772
# Episode:  85  terminated with Reward  87.0
# Time elapsed during EPISODE 85: 12.109026432037354 seconds = 0.202 minutes
#
# Training on EPISODE 86 with epsilon 0.17956282684956196
# Episode:  86  terminated with Reward  84.0
# Time elapsed during EPISODE 86: 11.738543272018433 seconds = 0.196 minutes
#
# Training on EPISODE 87 with epsilon 0.1759715703125707
# Episode:  87  terminated with Reward  44.0
# Time elapsed during EPISODE 87: 6.2050135135650635 seconds = 0.103 minutes
#
# Training on EPISODE 88 with epsilon 0.1724521389063193
# Episode:  88  terminated with Reward  92.0
# Time elapsed during EPISODE 88: 12.833461284637451 seconds = 0.214 minutes
#
# Training on EPISODE 89 with epsilon 0.16900309612819292
# Episode:  89  terminated with Reward  105.0
# Time elapsed during EPISODE 89: 14.728909015655518 seconds = 0.245 minutes
#
# Training on EPISODE 90 with epsilon 0.16562303420562907
# Episode:  90  terminated with Reward  41.0
# Time elapsed during EPISODE 90: 5.7922163009643555 seconds = 0.097 minutes
#
# Training on EPISODE 91 with epsilon 0.16231057352151648
# Episode:  91  terminated with Reward  160.0
# Time elapsed during EPISODE 91: 22.526143550872803 seconds = 0.375 minutes
#
# Training on EPISODE 92 with epsilon 0.15906436205108615
# Episode:  92  terminated with Reward  214.0
# Time elapsed during EPISODE 92: 30.05176043510437 seconds = 0.501 minutes
#
# Training on EPISODE 93 with epsilon 0.15588307481006441
# Episode:  93  terminated with Reward  43.0
# Time elapsed during EPISODE 93: 5.9110400676727295 seconds = 0.099 minutes
#
# Training on EPISODE 94 with epsilon 0.15276541331386312
# Episode:  94  terminated with Reward  114.0
# Time elapsed during EPISODE 94: 16.225841283798218 seconds = 0.27 minutes
#
# Training on EPISODE 95 with epsilon 0.14971010504758586
# Episode:  95  terminated with Reward  127.0
# Time elapsed during EPISODE 95: 17.997865200042725 seconds = 0.3 minutes
#
# Training on EPISODE 96 with epsilon 0.14671590294663414
# Episode:  96  terminated with Reward  103.0
# Time elapsed during EPISODE 96: 14.604483127593994 seconds = 0.243 minutes
#
# Training on EPISODE 97 with epsilon 0.14378158488770146
# Episode:  97  terminated with Reward  117.0
# Time elapsed during EPISODE 97: 16.58802318572998 seconds = 0.276 minutes
#
# Training on EPISODE 98 with epsilon 0.14090595318994742
# Episode:  98  terminated with Reward  110.0
# Time elapsed during EPISODE 98: 15.47516131401062 seconds = 0.258 minutes
#
# Training on EPISODE 99 with epsilon 0.13808783412614847
# Episode:  99  terminated with Reward  103.0
# Time elapsed during EPISODE 99: 14.798109769821167 seconds = 0.247 minutes
#
# Training on EPISODE 100 with epsilon 0.13532607744362551
# Episode:  100  terminated with Reward  118.0
# Time elapsed during EPISODE 100: 16.790884017944336 seconds = 0.28 minutes

# %% [markdown]
# ### 5. Test the trained by executing an episode

# %% [markdown]
# #### The test executes a complete episode without visualization, because of running in a JupyterNotebook. A test episode with visualization can be executed with the python script *dqn.py* available in the ArtificalIntelligence repository, in the DQN folder

# %%
def select_trained_agent_action(state, trained_model):
    q_values = trained_model.predict(state, verbose=0)
    return np.argmax(q_values[0])

# %%
env = gym.make('CartPole-v1', render_mode='human')
state, _ = env.reset()
state_size = env.observation_space.shape[0]
total_reward = 0
max_timesteps = 350

# Execute episode
for t in range(max_timesteps):
    print(f'Running frame {t+1}...', end='\r')
   
    state = state.reshape((1, state_size))
    action = select_trained_agent_action(state, dqn_agent.main_network)
    next_state, reward, terminal, _, _ = env.step(action)
   
    total_reward += reward
    state = next_state
   
env.close()
   
print(f'Test episode terminated with reward {total_reward} (Max Reward=350)')
# Out:
# Running frame 108...
# C:\Anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py:177: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# Test episode terminated with reward 107.0 (Max Reward=350)

# %% [markdown]
# ### 6. Plot mean rewards of the agent

# %%
import matplotlib.pyplot as plt

# %%
def plot_rewards(mean_range=1):
   
    # The parameter mean_range must allow equal separation of rewards
    if len(rewards) % mean_range != 0:
        raise ValueError
       
    # Calculate mean rewards
    mean_rewards = list()
    for i in range(round(len(rewards)/mean_range)):
        reward_on_range = rewards[i*mean_range:i*mean_range+mean_range]
        reward_on_range_mean = round(sum(reward_on_range)/len(reward_on_range))
        mean_rewards.append(reward_on_range_mean)
        
    average_reward = np.mean(rewards)
    print(f'Average reward for the entire training process:{average_reward}')

       
    plt.plot(range(len(mean_rewards)), mean_rewards, label='Mean Rewards')
    plt.axhline(y=average_reward, color='r', linestyle = '--', label='Average Reward')
    plt.legend()
    plt.xlabel('Episodes (in mean range)')
    plt.ylabel('Rewards')
    plt.title('Rewards vs Episodes')
    plt.show()

# %%
plot_rewards()
# Out:
# Average reward for the entire training process:81.2

# %% [markdown]
# ### 7. Plot values of moving average during the training

# %%
def moving_average(rewards, window_size):
    cum_sum = np.cumsum(np.insert(rewards,0,0))
    return (cum_sum[window_size:]-cum_sum[:-window_size]) / window_size

window_size = 10
avg_rewards = moving_average(rewards, window_size)

plt.figure(figsize=(10,5))
plt.plot(range(window_size, len(rewards)+1), avg_rewards)
plt.xlabel('Episode')
plt.ylabel('Average reward')
plt.title(f'Moving Average Reward (Window Size:{window_size})')
plt.show()

# %%
### 8. Plot values of epsilon during the training

# %%
def plot_epsilon_values():
    
    plt.plot(range(len(epsilon_values)), epsilon_values)
    plt.show()

# %%
plot_epsilon_values()
